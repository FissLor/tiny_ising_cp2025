# %%
import simtool.simtool as simtool

# Run all builds with a problem size L=1000
df = simtool.build_and_run('xoroshift', L=384)
print(df)
# Out:
# Building preset 'xoroshift' for L=384 in directory /home/lfissore/Documents/Facultad/paralela2025/tiny_ising/out/xoroshift_384 ...
# {'compiler': 'gcc', 'optimization_flags': '-O3', 'L': 384, 'metric': 15.388842, 'error': None}

# %%
df = simtool.build_and_run('gcc-O3', L=384)
print(df)
# Out:
# Building preset 'gcc-O3' for L=384 in directory /home/lfissore/Documents/Facultad/paralela2025/tiny_ising/out/gcc-O3_384 ...
# {'compiler': 'gcc', 'optimization_flags': '-O3', 'L': 384, 'metric': 26.940309, 'error': None}

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('results/xoroshift_384/table')
print(df)

# # Load data into a pandas dataframe
# df = pd.read_csv('../results/LAB1/sim_results_modified_code_flags_xorshift.csv')
df['version'] = 'modified'
df1 = pd.read_csv('results/gcc-O3_384/table')
df1['version'] = 'original'

df = pd.concat([df, df1])
# Use seaborn to create a line plot
sns.lineplot(x='# Temp', y='E', hue='version' , data=df)

# Set the plot title and axis labels
plt.title('Energy vs Temperature')
plt.xlabel('Temperature')
plt.ylabel('Energy')

# Show the plot
plt.show()
# Out:
#      # Temp         E       E^2        E^4         M       M^2           M^4
# 0      1.50 -1.949468  3.800429  14.443300  0.985978  0.972153  9.450827e-01
# 1      1.51 -1.949631  3.801062  14.448093  0.986087  0.972367  9.454981e-01
# 2      1.52 -1.947667  3.793408  14.389961  0.985482  0.971174  9.431800e-01
# 3      1.53 -1.944754  3.782070  14.304097  0.984622  0.969480  9.398937e-01
# 4      1.54 -1.942616  3.773758  14.241268  0.984039  0.968332  9.376677e-01
# ..      ...       ...       ...        ...       ...       ...           ...
# 146    2.96 -0.832655  0.693332   0.480757  0.015712  0.000300  1.432000e-07
# 147    2.97 -0.830404  0.689583   0.475559  0.007335  0.000070  8.800000e-09
# 148    2.98 -0.824344  0.679561   0.461854  0.006936  0.000057  5.100000e-09
# 149    2.99 -0.821696  0.675197   0.455925  0.005301  0.000050  8.900000e-09
# 150    3.00 -0.816976  0.667462   0.445539  0.009573  0.000111  2.060000e-08
#
# [151 rows x 7 columns]

# %%
import simtool.simtool as simtool

# Run all builds with a problem size L=1000
df = simtool.build_and_run('zero_padding', L=1000)
print(df)
# Out:
# Building preset 'zero_padding' for L=1000 in directory /home/lfissore/Documents/Facultad/paralela2025/tiny_ising/out/zero_padding_1000 ...
# {'compiler': 'gcc', 'optimization_flags': '-O3', 'L': 1000, 'metric': 125.288742, 'error': None}

# %%
df = simtool.build_and_run('gcc-O3', L=1000)
print(df)
# Out:
# Building preset 'gcc-O3' for L=1000 in directory /home/lfissore/Documents/Facultad/paralela2025/tiny_ising/out/gcc-O3_1000 ...
# {'compiler': 'gcc', 'optimization_flags': '-O3', 'L': 1000, 'metric': 223.823843, 'error': None}

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('results/zero_padding_1000/table')
print(df)

# # Load data into a pandas dataframe
# df = pd.read_csv('../results/LAB1/sim_results_modified_code_flags_xorshift.csv')
df['version'] = 'modified'
df1 = pd.read_csv('results/gcc-O3_1000/table')
df1['version'] = 'original'

df = pd.concat([df, df1])
# Use seaborn to create a line plot
sns.lineplot(x='# Temp', y='E', hue='version' , data=df)

# Set the plot title and axis labels
plt.title('Energy vs Temperature')
plt.xlabel('Temperature')
plt.ylabel('Energy')

# Show the plot
plt.show()
# Out:
#      # Temp         E       E^2        E^4         M       M^2           M^4
# 0      1.50 -1.946730  3.789759  14.362282  0.985031  0.970287  9.414562e-01
# 1      1.51 -1.945757  3.785970  14.333584  0.984764  0.969760  9.404353e-01
# 2      1.52 -1.943230  3.776142  14.259256  0.983973  0.968202  9.374162e-01
# 3      1.53 -1.940883  3.767028  14.190513  0.983287  0.966853  9.348049e-01
# 4      1.54 -1.939358  3.761109  14.145950  0.982854  0.966002  9.331602e-01
# ..      ...       ...       ...        ...       ...       ...           ...
# 146    2.96 -0.831276  0.691022   0.477518  0.002054  0.000005  0.000000e+00
# 147    2.97 -0.828897  0.687071   0.472069  0.002689  0.000010  2.000000e-10
# 148    2.98 -0.824522  0.679839   0.462187  0.003322  0.000015  5.000000e-10
# 149    2.99 -0.819907  0.672251   0.451931  0.002628  0.000009  1.000000e-10
# 150    3.00 -0.815412  0.664898   0.442095  0.001160  0.000002  0.000000e+00
#
# [151 rows x 7 columns]

# %%
import simtool.simtool as simtool

# Run all builds with a problem size L=1000
df = simtool.build_and_run('both', L=1000)
print(df)
# Out:
# Building preset 'both' for L=1000 in directory /home/lfissore/Documents/Facultad/paralela2025/tiny_ising/out/both_1000 ...
# {'compiler': 'gcc', 'optimization_flags': '-O3', 'L': 1000, 'metric': 98.281405, 'error': None}
