# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt



df = pd.read_csv('build/vectorizing_rb_update/table')
print(df)

# # Load data into a pandas dataframe
# df = pd.read_csv('../results/LAB1/sim_results_modified_code_flags_xorshift.csv')
df['version'] = 'rb_update'
df1 = pd.read_csv('build/vectorizing_rb_update_boltzmann/table')
df1['version'] = 'rb_update_boltzmann'

df2 = pd.read_csv('build/vectorizing_base/table')
df2['version'] = 'base'


df2 = pd.read_csv('build/vectorizing_simple_update/table')
df2['version'] = 'base'

df3 = pd.read_csv('build/vectorizing_rb_update_boltzmann_intrinsics/table')
df3['version'] = 'intrinsics'

df4 = pd.read_csv('build/openmp/table')
df4['version'] = 'openmp'


df = pd.concat([df2, df, df1, df3, df4])
# Use seaborn to create a line plot
sns.lineplot(x='# Temp', y='E', hue='version' , data=df)

# Set the plot title and axis labels
plt.title('Energía vs Temperatura')
plt.xlabel('Temperatura')
plt.ylabel('Energía')

# Show the plot
plt.show()
# Out:
#      # Temp         E       E^2        E^4         M       M^2           M^4
# 0      1.50 -1.943690  3.777934  14.272801  0.984190  0.968631  9.382461e-01
# 1      1.51 -1.941026  3.767581  14.194684  0.983285  0.966849  9.347974e-01
# 2      1.52 -1.939058  3.759949  14.137245  0.982776  0.965849  9.328650e-01
# 3      1.53 -1.936888  3.751537  14.074051  0.982184  0.964686  9.306192e-01
# 4      1.54 -1.935838  3.747472  14.043564  0.981811  0.963953  9.292064e-01
# ..      ...       ...       ...        ...       ...       ...           ...
# 146    2.96 -0.830231  0.689295   0.475160  0.004934  0.000032  1.900000e-09
# 147    2.97 -0.825680  0.681765   0.464853  0.006670  0.000075  1.590000e-08
# 148    2.98 -0.822558  0.676602   0.457794  0.003035  0.000013  3.000000e-10
# 149    2.99 -0.820573  0.673352   0.453437  0.008542  0.000112  3.350000e-08
# 150    3.00 -0.817038  0.667580   0.445738  0.003845  0.000022  1.000000e-09
#
# [151 rows x 7 columns]
# /tmp/ipykernel_5388/4072227605.py:40: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('build/vectorizing_rb_update/table')
print(df)

# # Load data into a pandas dataframe
# df = pd.read_csv('../results/LAB1/sim_results_modified_code_flags_xorshift.csv')
df['version'] = 'rb_update'
df1 = pd.read_csv('build/vectorizing_rb_update_boltzmann/table')
df1['version'] = 'rb_update_boltzmann'

#df2 = pd.read_csv('build/base/table')
#df2['version'] = 'base'


#df2 = pd.read_csv('build/rb_update_boltzmann/table')
#df2['version'] = 'base'

df3 = pd.read_csv('build/intrinsics/table')
df3['version'] = 'intrinsics'


df = pd.concat([ df, df1,  df3])
# Use seaborn to create a line pl
# Use seaborn to create a line plot
sns.lineplot(x='# Temp', y='M', hue='version', data=df)

# Set the plot title and axis labels
plt.title('Magnetización vs Temperatura')
plt.xlabel('Temperatura')
plt.ylabel('Magnetización')

# Show the plot
plt.show()
# Out:
#      # Temp         E       E^2        E^4         M       M^2           M^4
# 0      1.50 -1.943690  3.777934  14.272801  0.984190  0.968631  9.382461e-01
# 1      1.51 -1.941026  3.767581  14.194684  0.983285  0.966849  9.347974e-01
# 2      1.52 -1.939058  3.759949  14.137245  0.982776  0.965849  9.328650e-01
# 3      1.53 -1.936888  3.751537  14.074051  0.982184  0.964686  9.306192e-01
# 4      1.54 -1.935838  3.747472  14.043564  0.981811  0.963953  9.292064e-01
# ..      ...       ...       ...        ...       ...       ...           ...
# 146    2.96 -0.830231  0.689295   0.475160  0.004934  0.000032  1.900000e-09
# 147    2.97 -0.825680  0.681765   0.464853  0.006670  0.000075  1.590000e-08
# 148    2.98 -0.822558  0.676602   0.457794  0.003035  0.000013  3.000000e-10
# 149    2.99 -0.820573  0.673352   0.453437  0.008542  0.000112  3.350000e-08
# 150    3.00 -0.817038  0.667580   0.445738  0.003845  0.000022  1.000000e-09
#
# [151 rows x 7 columns]
# /tmp/ipykernel_5388/287547917.py:35: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# df = pd.read_csv('build/rb_update/table')
# print(df)

# # # Load data into a pandas dataframe
# # df = pd.read_csv('../results/LAB1/sim_results_modified_code_flags_xorshift.csv')
# df['version'] = 'rb_update'
df1 = pd.read_csv('build/base/table')
df1['version'] = 'base'


df2 = pd.read_csv('build/rb_update_boltzmann/table')
df2['version'] = 'rb_update_boltzmann'

df3 = pd.read_csv('build/intrinsics/table')
df3['version'] = 'intrinsics'


df = pd.concat([df2,  df1, df3])
# Use seaborn to create a line plot
sns.lineplot(x='# Temp', y='E', hue='version' , data=df)

# Set the plot title and axis labels
plt.title('Energía vs Temperatura')
plt.xlabel('Temperatura')
plt.ylabel('Energía')

# Show the plot
plt.show()
